# %%
#Api Access

# %%
# !pip install gtts

# %%
from gtts import gTTS
import os

text = "Hello, this is a simple example of text to speech conversion. I would like to welcome everybody in todays class"

speech = gTTS(text=text, lang='hi')

speech.save("output.mp3")

from google.colab import files

files.download("output.mp3")

from IPython.display import Audio

Audio("output.mp3")

#from IPython.display import FileLink
#FileLink("output.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install SpeechRecognition pydub

import speech_recognition as sr
from pydub import AudioSegment

mp3_file_path = "/content/drive/MyDrive/python-Vyankat sir/Audio notebook/output.mp3"
wav_file_path = "/content/drive/MyDrive/python-Vyankat sir/Audio notebook/outputwav.wav"  #wav (waveform audio file format) #to remove background noise

audio = AudioSegment.from_mp3(mp3_file_path)
audio.export(wav_file_path, format='wav')

recognizer = sr.Recognizer()

audio_file = sr.AudioFile(wav_file_path)

with audio_file as source:
    audio_data = recognizer.record(source)
    text = recognizer.recognize_google(audio_data)

print("Converted text: ",text)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# Converted text:  hello this is a simple example of text-to-speech conversion I would like to welcome everybody in today's class

# %%
import requests

api_key = "308838bdda012c96df370e5218870f67"
city_name = "Chittoor"

base_url = f"http://api.openweathermap.org/data/2.5/weather?q={city_name}&appid={api_key}"

response = requests.get(base_url)

weather_data = response.json()

if response.status_code == 200:

    main = weather_data["main"]
    temperature = main ["temp"]
    humidity = main["humidity"]
    weather_description = weather_data["weather"][0]["description"]

    temperature_celsius = temperature - 273.15

    print(f"Temperature : {temperature_celsius: 2f}°C")
    print(f"Humidity: {humidity}%")
    print(f"Description: {weather_description.capitalize()}")

else:
    print("City Not found or API request failed!")
# Out:
# Temperature :  31.080000°C
# Humidity: 46%
# Description: Scattered clouds
