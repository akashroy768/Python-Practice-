# %%
import pandas as pd 

file_path = "D:/Documents/Documents/Besant technology/5.python/code/mtcars2.csv"

cars = pd.read_csv(file_path)
print(cars)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4           Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  17.02   1   0
# 7            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 8             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# ...

# %%
cars.shape
# Out:
# (44, 12)

# %%
type(cars)
# Out:
# pandas.core.frame.DataFrame

# %%
#first 5 records it will give if u pass value 10 then 10 data will show 
cars.head()
# Out:
#        Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0       Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1   Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2      Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3  Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4     Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     3

# %%
#last 5 records it will give 
cars.tail()
# Out:
#            Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 39  Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   0
# 40           Fiat 128  32.4    4   78.7   66  4.08  2.200  17.42   1   1
# 41        Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   1
# 42     Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   1
# 43      Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   0
#
#     gear  carb
# 39     3     4
# 40     4     1
# 41     4     2
# 42     4     1
# 43     3     1

# %%
#it will give how many null values are their is datasets
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  44 non-null     object
#  1   mpg         44 non-null     float64
#  2   cyl         44 non-null     int64
#  3   disp        44 non-null     float64
#  4   hp          44 non-null     int64
#  5   drat        44 non-null     float64
#  6   wt          44 non-null     float64
#  7   qsec        44 non-null     float64
#  8   vs          44 non-null     int64
#  9   am          44 non-null     int64
#  10  gear        44 non-null     int64
#  11  carb        44 non-null     int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 4.3+ KB

# %%
mean_values = cars.mean(numeric_only=True)
print(mean_values)
# Out:
# mpg      19.722727
# cyl       6.318182
# disp    244.556818
# hp      146.795455
# drat      3.559773
# wt        3.327750
# qsec     17.750227
# vs        0.409091
# am        0.363636
# gear      3.568182
# carb      2.727273
# dtype: float64

# %%
median_values = cars.median(numeric_only=True)
print(median_values)
# Out:
# mpg      18.400
# cyl       7.000
# disp    266.900
# hp      150.000
# drat      3.580
# wt        3.435
# qsec     17.420
# vs        0.000
# am        0.000
# gear      3.000
# carb      2.000
# dtype: float64

# %%
std_values = cars.std(numeric_only = True)
std_values
# Out:
# mpg       6.780679
# cyl       1.827092
# disp    134.989997
# hp       66.454244
# drat      0.559657
# wt        1.113763
# qsec      1.535409
# vs        0.497350
# am        0.486607
# gear      0.695424
# carb      1.515250
# dtype: float64

# %%
cars.max(numeric_only=True)
# Out:
# mpg      33.900
# cyl       8.000
# disp    472.000
# hp      335.000
# drat      4.930
# wt        5.424
# qsec     22.900
# vs        1.000
# am        1.000
# gear      5.000
# carb      8.000
# dtype: float64

# %%
cars.min(numeric_only=True)
# Out:
# mpg     10.400
# cyl      4.000
# disp    71.100
# hp      52.000
# drat     2.760
# wt       1.513
# qsec    14.500
# vs       0.000
# am       0.000
# gear     3.000
# carb     1.000
# dtype: float64

# %%
cars.count()
# Out:
# Unnamed: 0    44
# mpg           44
# cyl           44
# disp          44
# hp            44
# drat          44
# wt            44
# qsec          44
# vs            44
# am            44
# gear          44
# carb          44
# dtype: int64

# %%
#it will give the descricptive summary od dataset
cars.describe()
# Out:
#              mpg        cyl        disp          hp       drat         wt  \
# count  44.000000  44.000000   44.000000   44.000000  44.000000  44.000000
# mean   19.722727   6.318182  244.556818  146.795455   3.559773   3.327750
# std     6.780679   1.827092  134.989997   66.454244   0.559657   1.113763
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.200000   4.000000  120.250000   96.500000   3.077500   2.465000
# 50%    18.400000   7.000000  266.900000  150.000000   3.580000   3.435000
# 75%    22.800000   8.000000  350.250000  186.250000   3.920000   3.780000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             qsec         vs         am       gear       carb
# count  44.000000  44.000000  44.000000  44.000000  44.000000
# mean   17.750227   0.409091   0.363636   3.568182   2.727273
# std     1.535409   0.497350   0.486607   0.695424   1.515250
# ...

# %%
#data cleaning

# %%
print(cars)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4           Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  17.02   1   0
# 7            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 8             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# ...

# %%
cars = cars.rename(columns = {'Unnamed: 0':'model'})
print(cars)
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4           Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  17.02   1   0
# 7            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 8             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# ...

# %%
cars = cars.rename(columns = {'wt':'weight'})
print(cars)
# Out:
#                   model   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   0
# 4           Merc 450SLC  15.2    8  275.8  180  3.07   3.780  18.00   0   0
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   0
# 6               Valiant  18.1    6  225.0  105  2.76   3.460  17.02   1   0
# 7            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   0
# 8             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   0
# 9              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   0
# 10             Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   0
# ...

# %%
#fill the null values with mean of the column
cars.qsec = cars.qsec.fillna(cars.qsec.mean())
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4           Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  17.02   1   0
# 7            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 8             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# ...

# %%
import pandas as pd
data =pd.read_excel("D:/Documents/Documents/Besant technology/5.python/code/Sample - Superstore.xls")
print(data)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0          1  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1          2  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2          3  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3          4  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4          5  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989    9990  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990    9991  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991    9992  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992    9993  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993    9994  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# 0       CG-12520       Claire Gute   Consumer  United States        Henderson
# ...

# %%
# !pip install xlrd

# %%
data = data.drop(columns=['Customer ID'])

# %%
#to drop the rows we will use index
# cars = cars.drop(index=2)
# cars

# %%
#indexing by position

# %%
#view only hp column
print(cars.iloc[:,4])  #[: (rows), 4(columns)]
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     180
# 5     175
# 6     105
# 7     245
# 8      62
# 9      95
# 10    123
# 11    123
# 12    180
# 13    205
# 14    180
# 15    180
# 16    150
# 17    205
# 18    215
# 19    230
# 20     66
# 21     52
# 22     65
# 23     97
# 24    150
# 25    150
# 26    150
# 27    245
# 28    175
# 29     66
# 30     91
# 31    113
# 32    264
# 33    175
# 34    335
# 35    109
# 36    150
# 37    205
# 38    215
# 39    230
# 40     66
# 41     52
# 42     65
# 43     97
# Name: hp, dtype: int64

# %%
#first five records of hp column
cars.iloc[0:5,4]  #5-1 = 4th index
# Out:
# 0    110
# 1    110
# 2     93
# 3    110
# 4    180
# Name: hp, dtype: int64

# %%
#all rows, all columns 

cars.iloc[: , :]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4           Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   0
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 6               Valiant  18.1    6  225.0  105  2.76  3.460  17.02   1   0
# 7            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 8             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 9              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# ...

# %%
#for attributes from hp to carb see all the records from index 6 
cars.iloc[6:,4:]

#view attributes from drat to vs and records from 2nd index to 10th index
cars.iloc[2:11,5:9]
# Out:
#     drat     wt   qsec  vs
# 2   3.85  2.320  18.61   1
# 3   3.08  3.215  19.44   1
# 4   3.07  3.780  18.00   0
# 5   3.15  3.440  17.02   0
# 6   2.76  3.460  17.02   1
# 7   3.21  3.570  15.84   0
# 8   3.69  3.190  20.00   1
# 9   3.92  3.150  22.90   1
# 10  3.92  3.440  18.30   1

# %%
#now we want to look at all rows and only the first column 
cars.iloc[:,0]
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4             Merc 450SLC
# 5       Hornet Sportabout
# 6                 Valiant
# 7              Duster 360
# 8               Merc 240D
# 9                Merc 230
# 10               Merc 280
# 11              Merc 280C
# 12             Merc 450SE
# 13     Cadillac Fleetwood
# 14             Merc 450SL
# 15            Merc 450SLC
# 16            AMC Javelin
# 17     Cadillac Fleetwood
# 18    Lincoln Continental
# 19      Chrysler Imperial
# 20               Fiat 128
# 21            Honda Civic
# 22         Toyota Corolla
# 23          Toyota Corona
# 24            AMC Javelin
# 25       Dodge Challenger
# 26            AMC Javelin
# 27             Camaro Z28
# 28       Pontiac Firebird
# 29              Fiat X1-9
# 30          Porsche 914-2
# 31           Lotus Europa
# 32         Ford Pantera L
# 33           Ferrari Dino
# 34          Maserati Bora
# ...

# %%
#indexing by label

# %%
#see all the record of mpg column
cars.loc[:,"mpg"]
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     15.2
# 5     18.7
# 6     18.1
# 7     14.3
# 8     24.4
# 9     22.8
# 10    19.2
# 11    17.8
# 12    16.4
# 13    10.4
# 14    17.3
# 15    15.2
# 16    15.2
# 17    10.4
# 18    10.4
# 19    14.7
# 20    32.4
# 21    30.4
# 22    33.9
# 23    21.5
# 24    15.2
# 25    15.5
# 26    15.2
# 27    13.3
# 28    19.2
# 29    27.3
# 30    26.0
# 31    30.4
# 32    15.8
# 33    19.7
# 34    15.0
# 35    21.4
# 36    15.2
# 37    10.4
# 38    10.4
# 39    14.7
# 40    32.4
# 41    30.4
# 42    33.9
# 43    21.5
# Name: mpg, dtype: float64

# %%
#display the records from  index 0 to index 6 from mpg column
cars.loc[0:6,"mpg"]
# Out:
# 0    21.0
# 1    21.0
# 2    22.8
# 3    21.4
# 4    15.2
# 5    18.7
# 6    18.1
# Name: mpg, dtype: float64

# %%
#see the first 7 records from mpg to qsec column
cars.loc[0:6,"mpg":"qsec"]
# Out:
#     mpg  cyl   disp   hp  drat  weight   qsec
# 0  21.0    6  160.0  110  3.90   2.620  16.46
# 1  21.0    6  160.0  110  3.90   2.875  17.02
# 2  22.8    4  108.0   93  3.85   2.320  18.61
# 3  21.4    6  258.0  110  3.08   3.215  19.44
# 4  15.2    8  275.8  180  3.07   3.780  18.00
# 5  18.7    8  360.0  175  3.15   3.440  17.02
# 6  18.1    6  225.0  105  2.76   3.460  17.02

# %%
#set value 1 to column 'am' auromated = 0, manual =1
cars['am'] = 1
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   1
# 4           Merc 450SLC  15.2    8  275.8  180  3.07   3.780  18.00   0   1
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   1
# 6               Valiant  18.1    6  225.0  105  2.76   3.460  17.02   1   1
# 7            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   1
# 8             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   1
# 9              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   1
# 10             Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   1
# ...

# %%
#double up records in 'am' using lambda fxn
f = lambda x: x*2
cars['am']=cars['am'].apply(f)
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat  weight   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90   2.620  16.46   0   2
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90   2.875  17.02   0   2
# 2            Datsun 710  22.8    4  108.0   93  3.85   2.320  18.61   1   2
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08   3.215  19.44   1   2
# 4           Merc 450SLC  15.2    8  275.8  180  3.07   3.780  18.00   0   2
# 5     Hornet Sportabout  18.7    8  360.0  175  3.15   3.440  17.02   0   2
# 6               Valiant  18.1    6  225.0  105  2.76   3.460  17.02   1   2
# 7            Duster 360  14.3    8  360.0  245  3.21   3.570  15.84   0   2
# 8             Merc 240D  24.4    4  146.7   62  3.69   3.190  20.00   1   2
# 9              Merc 230  22.8    4  140.8   95  3.92   3.150  22.90   1   2
# 10             Merc 280  19.2    6  167.6  123  3.92   3.440  18.30   1   2
# ...
